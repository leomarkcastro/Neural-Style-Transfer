# %% [markdown]
# # **SETTING UP PHASE**

# %% [markdown]
# This part sets up the working directory of the application. Its important that in your google drive, you have a folder named "art", else, the scripts following this will just not work

# %%
# %cd "/content" 
# use this if you want to connect to your google drive or want to refresh the data here
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
#4/1AY0e-g5ecl1iboxb3ENYqH2yqKq5fnTbuZslgHgIDa9LG4d6A_sAhOL-PXU
# Out:
# /content
# Mounted at /content/drive

# %%
run_what = False #excel = True , auto = False

# %%
# variables

working_folder = "/content/drive/MyDrive/art/"

#change the working directory

# %cd {working_folder} 
! dir
# Out:
# /content/drive/MyDrive/art
# artMaker.py	denoiser.py	   requirements.txt  style-expressionism
# batch_start.py	models		   start.py	     style-texture
# _cache.json	model_uploader.py  style	     tasks.xlsx
# content		output		   style1.jpg
# content1.png	__pycache__	   style-abstract

# %% [markdown]
# In this part, we install all the python packages neeeded to run the app script

# %%
# !pip install -r "/content/drive/MyDrive/art/requirements.txt"
# Out:
# ...
#      |████████████████████████████████| 112kB 25.0MB/s
# ...
#      |████████████████████████████████| 153kB 41.3MB/s
# ...
#   Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %% [markdown]
# You only run this if you dont have the models yet, but the "art" folder I provide already has the models fodler

# %%
#!neural-style -download_models "/content/drive/MyDrive/art/models"

# %% [markdown]
# # **RUNNING THE APPLICATION / FROM AN EXCEL**

# %% [markdown]
# Note: In case you changed the excel file in the google drive. You have to unconnect then reconnect the google drive here.

# %% [markdown]
# This calls the real meat of the app

# %%
if run_what:
  import pandas as pd

  df = pd.read_excel (r'tasks.xlsx', sheet_name='LayoutData')
  pd.set_option('display.max_columns', None)
  pd.set_option('display.max_rows', None)

  print (df)

# %%
if run_what:
  # !python start.py

# %% [markdown]
# # **RUNNING THE APPLICATION /AUTO GET**

# %% [markdown]
# Note: In case you changed the excel file in the google drive. You have to unconnect then reconnect the google drive here.

# %% [markdown]
# This calls the real meat of the app

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp37-none-any.whl size=7411 sha256=219daefd81503298b2c834c4f9573f19e37b146dfd78ac6f4a471bca74338ff1
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# Successfully built gputil
# ...
# Gen RAM Free: 12.7 GB  | Proc size: 119.0 MB
# GPU RAM Free: 15109MB | Used: 0MB | Util   0% | Total 15109MB

# %%
if not run_what:
  from batch_start import jobTask
  import json

  template = {

      "style_image": "!rnd1",
      "content_image": "",

      "output_size": "512",

      "iterations": "1000",
      "create_iter": "100",
      
      "model": "accurate",
      "cpu": "gpu_modified",

      "style_scale": "1.0",

      "content_weight": "5",
      "style_weight": "150",
      "tv_weight": "0.001",

      "content_layers": "relu3_3",
      "style_layers": "relu1_2,relu2_2,relu3_3,relu4_3",
      
      "original_color": "No",

  }

  template_task = [template] * 7

  with open('_cache.json', 'w+') as fp:
    json.dump(template_task, fp) 

  source = "content-2"
  style = "style-special2"

  # !python batch_start.py _cache.json {source} {style}
# Out:
# ------------------------
#
#
# DOING PROCESS [1][1/7] OF 2
# test
# neural-style -style_image "style-special2/stained2.jpg" -content_image "proc/ab340321_test.png" -output_image "output/outputset_0407 143250_30304c86/test_0407 143250_31bea533/stylized_test_0407 143250.png" -num_iterations 1000 -save_iter 100 -model_file "models/vgg19-d01eb7cb.pth" -gpu 0 -backend cudnn -cudnn_autotune -optimizer lbfgs -image_size 512 -style_scale 1.0 -content_weight 5 -style_weight 150 -tv_weight 0.001 -content_layers relu3_3 -style_layers relu1_2,relu2_2,relu3_3,relu4_3
#
# VGG-19 Architecture Detected
# Successfully loaded models/vgg19-d01eb7cb.pth
# conv1_1: 64 3 3 3
# conv1_2: 64 64 3 3
# conv2_1: 128 64 3 3
# conv2_2: 128 128 3 3
# conv3_1: 256 128 3 3
# conv3_2: 256 256 3 3
# conv3_3: 256 256 3 3
# conv3_4: 256 256 3 3
# conv4_1: 512 256 3 3
# conv4_2: 512 512 3 3
# conv4_3: 512 512 3 3
# conv4_4: 512 512 3 3
# conv5_1: 512 512 3 3
# conv5_2: 512 512 3 3
# conv5_3: 512 512 3 3
# ...

# %%
#!neural-style -style_image "style-abstract/style5.jpg" -content_image "content/content1.png" -output_image "output/stylized_content1_0406 050641.png" -optimizer adam -tv_weight 0 -original_colors 0 -backend cudnn
